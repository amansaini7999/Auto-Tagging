# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.applications import VGG16
from keras.layers import Dense, GlobalAveragePooling2D, Dropout
from keras.models import Model
from keras_preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
# Out:
# Using TensorFlow backend.
# /home/aman/.local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/aman/.local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/aman/.local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/aman/.local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/aman/.local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/aman/.local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/aman/.local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/aman/.local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/aman/.local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/aman/.local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/aman/.local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/aman/.local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
traindf = pd.read_csv("dataset/train.csv")
testdf = pd.read_csv("dataset/test.csv")

# %%
traindf.head()
# Out:
#             Image   Class
# 0   image7042.jpg    Food
# 1   image3327.jpg    misc
# 2  image10335.jpg  Attire
# 3   image8019.jpg    Food
# 4   image2128.jpg  Attire

# %%
testdf.head()
# Out:
#             Image
# 0   image6245.jpg
# 1  image10409.jpg
# 2   image8692.jpg
# 3  image10517.jpg
# 4   image2580.jpg

# %%
len(traindf)
# Out:
# 5983

# %%
len(testdf)
# Out:
# 3219

# %%
traindf.groupby(by = 'Class', axis=0).count()
# Out:
#                       Image
# Class
# Attire                 1691
# Decorationandsignage    743
# Food                   2278
# misc                   1271

# %%
trainPath = "dataset/Train Images/"
testPath = "dataset/Test Images/"

# %%
datagen=ImageDataGenerator(rescale=1./255., validation_split=0.0808, horizontal_flip=True)

# %%
trainGenerator=datagen.flow_from_dataframe(dataframe=traindf,
                                           directory=trainPath,
                                           x_col="Image",
                                           y_col="Class",
                                           batch_size=50,
                                           subset="training",
                                           seed=42,
                                           shuffle=True,
                                           class_mode="categorical",
                                           target_size=(60,80))

validGenerator=datagen.flow_from_dataframe(dataframe=traindf,
                                           directory=trainPath,
                                           x_col="Image",
                                           y_col="Class",
                                           batch_size=23,
                                           subset="validation",
                                           seed=42,
                                           shuffle=True,
                                           class_mode="categorical",
                                           target_size=(60,80))
# Out:
# Found 5500 validated image filenames belonging to 4 classes.
# Found 483 validated image filenames belonging to 4 classes.

# %%
testDatagen=ImageDataGenerator(rescale=1./255.)

testGenerator=testDatagen.flow_from_dataframe(dataframe=testdf,
                                                directory=testPath,
                                                x_col="Image",
                                                y_col=None,
                                                batch_size=29,
                                                seed=42,
                                                shuffle=False,
                                                class_mode=None,
                                                target_size=(60,80))
# Out:
# Found 3219 validated image filenames.

# %%
def buildModel():
    baseModel = VGG16(input_shape=(60, 80, 3), weights='imagenet',include_top=False)
    model = Sequential()
    model.add(baseModel)
    model.add(GlobalAveragePooling2D())
    
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(4, activation='softmax'))
    
    baseModel.trainable=False
    
    set_trainable = False
    for layer in baseModel.layers:
        if layer.name == 'layer_name':
            set_trainable = True
        
        if set_trainable:
            layer.trainable = True
        else:
            layer.trainable = False
    
    model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'])
    
    return baseModel, model

# %%
baseModel, model = buildModel()

baseModel.summary()
model.summary()
# Out:
# WARNING:tensorflow:From /home/aman/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 60, 80, 3)         0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 60, 80, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 60, 80, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 30, 40, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 30, 40, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 30, 40, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 15, 20, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 15, 20, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 15, 20, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 15, 20, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 7, 10, 256)        0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 7, 10, 512)        1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 7, 10, 512)        2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 7, 10, 512)        2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 3, 5, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 3, 5, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 3, 5, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 3, 5, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 1, 2, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 1, 2, 512)         14714688
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 1028
# =================================================================
# Total params: 14,847,044
# Trainable params: 132,356
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
STEP_SIZE_TRAIN=trainGenerator.n//trainGenerator.batch_size
STEP_SIZE_VALID=validGenerator.n//validGenerator.batch_size

checkpointer = ModelCheckpoint(filepath='weights/model.ckpt', verbose=1, save_best_only=True)

# %%
model.fit_generator(generator=trainGenerator, steps_per_epoch=STEP_SIZE_TRAIN, validation_data=validGenerator, validation_steps=STEP_SIZE_VALID, epochs=50, verbose=1, callbacks=[checkpointer])
# Out:
# WARNING:tensorflow:From /home/aman/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/50
# 110/110 [==============================] - 123s 1s/step - loss: 1.1313 - accuracy: 0.5064 - val_loss: 1.2694 - val_accuracy: 0.5424
#
# Epoch 00001: val_loss improved from inf to 1.26943, saving model to weights/model.ckpt
# Epoch 2/50
# 110/110 [==============================] - 124s 1s/step - loss: 0.9680 - accuracy: 0.5951 - val_loss: 1.0900 - val_accuracy: 0.5652
#
# Epoch 00002: val_loss improved from 1.26943 to 1.09000, saving model to weights/model.ckpt
# Epoch 3/50
# 110/110 [==============================] - 125s 1s/step - loss: 0.9185 - accuracy: 0.6240 - val_loss: 0.8169 - val_accuracy: 0.5590
#
# Epoch 00003: val_loss improved from 1.09000 to 0.81694, saving model to weights/model.ckpt
# Epoch 4/50
# 110/110 [==============================] - 129s 1s/step - loss: 0.8714 - accuracy: 0.6467 - val_loss: 0.9053 - val_accuracy: 0.5797
#
# Epoch 00004: val_loss did not improve from 0.81694
# Epoch 5/50
# 110/110 [==============================] - 140s 1s/step - loss: 0.8472 - accuracy: 0.6509 - val_loss: 0.9611 - val_accuracy: 0.5797
#
# Epoch 00005: val_loss did not improve from 0.81694
# Epoch 6/50
# 110/110 [==============================] - 166s 2s/step - loss: 0.8148 - accuracy: 0.6747 - val_loss: 1.1563 - val_accuracy: 0.6066
#
# Epoch 00006: val_loss did not improve from 0.81694
# Epoch 7/50
# 110/110 [==============================] - 149s 1s/step - loss: 0.7870 - accuracy: 0.6811 - val_loss: 1.2322 - val_accuracy: 0.6211
#
# Epoch 00007: val_loss did not improve from 0.81694
# Epoch 8/50
# 110/110 [==============================] - 145s 1s/step - loss: 0.7623 - accuracy: 0.6993 - val_loss: 0.7474 - val_accuracy: 0.6066
#
# Epoch 00008: val_loss improved from 0.81694 to 0.74742, saving model to weights/model.ckpt
# Epoch 9/50
# 110/110 [==============================] - 192s 2s/step - loss: 0.7316 - accuracy: 0.7140 - val_loss: 0.9078 - val_accuracy: 0.6232
#
# Epoch 00009: val_loss did not improve from 0.74742
# Epoch 10/50
# 110/110 [==============================] - 127s 1s/step - loss: 0.7045 - accuracy: 0.7225 - val_loss: 0.7915 - val_accuracy: 0.6128
#
# Epoch 00010: val_loss did not improve from 0.74742
# Epoch 11/50
# 110/110 [==============================] - 126s 1s/step - loss: 0.6843 - accuracy: 0.7291 - val_loss: 0.8846 - val_accuracy: 0.6149
#
# Epoch 00011: val_loss did not improve from 0.74742
# Epoch 12/50
# 110/110 [==============================] - 126s 1s/step - loss: 0.6632 - accuracy: 0.7364 - val_loss: 0.8790 - val_accuracy: 0.6066
#
# Epoch 00012: val_loss did not improve from 0.74742
# Epoch 13/50
# 110/110 [==============================] - 125s 1s/step - loss: 0.6359 - accuracy: 0.7518 - val_loss: 1.0303 - val_accuracy: 0.5839
#
# Epoch 00013: val_loss did not improve from 0.74742
# Epoch 14/50
# 110/110 [==============================] - 125s 1s/step - loss: 0.6142 - accuracy: 0.7647 - val_loss: 1.1002 - val_accuracy: 0.6128
#
# Epoch 00014: val_loss did not improve from 0.74742
# Epoch 15/50
# 110/110 [==============================] - 125s 1s/step - loss: 0.5901 - accuracy: 0.7764 - val_loss: 0.7198 - val_accuracy: 0.6170
#
# Epoch 00015: val_loss improved from 0.74742 to 0.71984, saving model to weights/model.ckpt
# Epoch 16/50
# 110/110 [==============================] - 174s 2s/step - loss: 0.5722 - accuracy: 0.7809 - val_loss: 1.0153 - val_accuracy: 0.6025
#
# Epoch 00016: val_loss did not improve from 0.71984
# Epoch 17/50
# 110/110 [==============================] - 168s 2s/step - loss: 0.5471 - accuracy: 0.7942 - val_loss: 1.0590 - val_accuracy: 0.5901
#
# Epoch 00017: val_loss did not improve from 0.71984
# Epoch 18/50
# 110/110 [==============================] - 162s 1s/step - loss: 0.5353 - accuracy: 0.7960 - val_loss: 0.8236 - val_accuracy: 0.6004
#
# Epoch 00018: val_loss did not improve from 0.71984
# Epoch 19/50
# 110/110 [==============================] - 162s 1s/step - loss: 0.5005 - accuracy: 0.8160 - val_loss: 0.5528 - val_accuracy: 0.6294
#
# Epoch 00019: val_loss improved from 0.71984 to 0.55278, saving model to weights/model.ckpt
# Epoch 20/50
# 110/110 [==============================] - 167s 2s/step - loss: 0.4877 - accuracy: 0.8193 - val_loss: 0.8598 - val_accuracy: 0.6025
#
# Epoch 00020: val_loss did not improve from 0.55278
# Epoch 21/50
# 110/110 [==============================] - 171s 2s/step - loss: 0.4669 - accuracy: 0.8262 - val_loss: 1.2338 - val_accuracy: 0.6046
#
# Epoch 00021: val_loss did not improve from 0.55278
# Epoch 22/50
# 110/110 [==============================] - 172s 2s/step - loss: 0.4444 - accuracy: 0.8404 - val_loss: 0.9316 - val_accuracy: 0.6128
#
# Epoch 00022: val_loss did not improve from 0.55278
# Epoch 23/50
# 110/110 [==============================] - 171s 2s/step - loss: 0.4191 - accuracy: 0.8487 - val_loss: 1.1112 - val_accuracy: 0.6066
#
# Epoch 00023: val_loss did not improve from 0.55278
# Epoch 24/50
# 110/110 [==============================] - 175s 2s/step - loss: 0.4082 - accuracy: 0.8575 - val_loss: 1.3472 - val_accuracy: 0.6066
#
# Epoch 00024: val_loss did not improve from 0.55278
# Epoch 25/50
# 110/110 [==============================] - 174s 2s/step - loss: 0.3938 - accuracy: 0.8615 - val_loss: 0.9477 - val_accuracy: 0.6170
#
# Epoch 00025: val_loss did not improve from 0.55278
# Epoch 26/50
# 110/110 [==============================] - 176s 2s/step - loss: 0.3788 - accuracy: 0.8651 - val_loss: 1.2717 - val_accuracy: 0.6087
#
# Epoch 00026: val_loss did not improve from 0.55278
# Epoch 27/50
# 110/110 [==============================] - 178s 2s/step - loss: 0.3637 - accuracy: 0.8727 - val_loss: 0.8551 - val_accuracy: 0.5942
#
# Epoch 00027: val_loss did not improve from 0.55278
# Epoch 28/50
# 110/110 [==============================] - 182s 2s/step - loss: 0.3441 - accuracy: 0.8793 - val_loss: 1.1138 - val_accuracy: 0.5963
#
# Epoch 00028: val_loss did not improve from 0.55278
# Epoch 29/50
# 110/110 [==============================] - 190s 2s/step - loss: 0.3382 - accuracy: 0.8796 - val_loss: 1.2666 - val_accuracy: 0.5859
#
# Epoch 00029: val_loss did not improve from 0.55278
# Epoch 30/50
# 110/110 [==============================] - 182s 2s/step - loss: 0.3229 - accuracy: 0.8878 - val_loss: 0.7047 - val_accuracy: 0.6108
#
# Epoch 00030: val_loss did not improve from 0.55278
# Epoch 31/50
# 110/110 [==============================] - 177s 2s/step - loss: 0.3086 - accuracy: 0.8944 - val_loss: 1.4841 - val_accuracy: 0.6087
#
# Epoch 00031: val_loss did not improve from 0.55278
# Epoch 32/50
# 110/110 [==============================] - 174s 2s/step - loss: 0.2980 - accuracy: 0.8995 - val_loss: 1.5391 - val_accuracy: 0.5880
#
# Epoch 00032: val_loss did not improve from 0.55278
# Epoch 33/50
# 110/110 [==============================] - 172s 2s/step - loss: 0.2829 - accuracy: 0.9027 - val_loss: 1.4894 - val_accuracy: 0.6004
#
# Epoch 00033: val_loss did not improve from 0.55278
# Epoch 34/50
# 110/110 [==============================] - 170s 2s/step - loss: 0.2776 - accuracy: 0.9042 - val_loss: 1.8366 - val_accuracy: 0.5756
#
# Epoch 00034: val_loss did not improve from 0.55278
# Epoch 35/50
# 110/110 [==============================] - 169s 2s/step - loss: 0.2528 - accuracy: 0.9180 - val_loss: 0.9991 - val_accuracy: 0.5735
#
# Epoch 00035: val_loss did not improve from 0.55278
# Epoch 36/50
# 110/110 [==============================] - 168s 2s/step - loss: 0.2540 - accuracy: 0.9140 - val_loss: 1.1139 - val_accuracy: 0.6066
#
# Epoch 00036: val_loss did not improve from 0.55278
# Epoch 37/50
# 110/110 [==============================] - 167s 2s/step - loss: 0.2426 - accuracy: 0.9200 - val_loss: 1.2664 - val_accuracy: 0.5839
#
# Epoch 00037: val_loss did not improve from 0.55278
# Epoch 38/50
# 110/110 [==============================] - 164s 1s/step - loss: 0.2358 - accuracy: 0.9271 - val_loss: 0.9749 - val_accuracy: 0.5839
#
# Epoch 00038: val_loss did not improve from 0.55278
# Epoch 39/50
# 110/110 [==============================] - 165s 2s/step - loss: 0.2304 - accuracy: 0.9225 - val_loss: 1.3546 - val_accuracy: 0.5549
#
# Epoch 00039: val_loss did not improve from 0.55278
# Epoch 40/50
# 110/110 [==============================] - 165s 2s/step - loss: 0.2208 - accuracy: 0.9300 - val_loss: 1.4324 - val_accuracy: 0.5942
# Epoch 00040: val_loss did not improve from 0.55278
# Epoch 41/50
# 110/110 [==============================] - 163s 1s/step - loss: 0.2175 - accuracy: 0.9271 - val_loss: 1.8614 - val_accuracy: 0.5942
#
# Epoch 00041: val_loss did not improve from 0.55278
# Epoch 42/50
# 110/110 [==============================] - 162s 1s/step - loss: 0.1935 - accuracy: 0.9436 - val_loss: 1.3546 - val_accuracy: 0.5963
#
# Epoch 00042: val_loss did not improve from 0.55278
# Epoch 43/50
# 110/110 [==============================] - 162s 1s/step - loss: 0.1942 - accuracy: 0.9400 - val_loss: 0.5316 - val_accuracy: 0.6046
#
# Epoch 00043: val_loss improved from 0.55278 to 0.53157, saving model to weights/model.ckpt
# Epoch 44/50
# 110/110 [==============================] - 162s 1s/step - loss: 0.1883 - accuracy: 0.9411 - val_loss: 1.6561 - val_accuracy: 0.5735
#
# Epoch 00044: val_loss did not improve from 0.53157
# Epoch 45/50
# 110/110 [==============================] - 163s 1s/step - loss: 0.1885 - accuracy: 0.9378 - val_loss: 1.1965 - val_accuracy: 0.5921
#
# Epoch 00045: val_loss did not improve from 0.53157
# Epoch 46/50
# 110/110 [==============================] - 165s 1s/step - loss: 0.1732 - accuracy: 0.9485 - val_loss: 1.8803 - val_accuracy: 0.5818
#
# Epoch 00046: val_loss did not improve from 0.53157
# Epoch 47/50
# 110/110 [==============================] - 162s 1s/step - loss: 0.1701 - accuracy: 0.9484 - val_loss: 1.6405 - val_accuracy: 0.5776
#
# Epoch 00047: val_loss did not improve from 0.53157
# Epoch 48/50
# 110/110 [==============================] - 138s 1s/step - loss: 0.1677 - accuracy: 0.9462 - val_loss: 2.1365 - val_accuracy: 0.5880
#
# Epoch 00048: val_loss did not improve from 0.53157
# Epoch 49/50
# 110/110 [==============================] - 125s 1s/step - loss: 0.1643 - accuracy: 0.9467 - val_loss: 1.6705 - val_accuracy: 0.5756
#
# Epoch 00049: val_loss did not improve from 0.53157
# Epoch 50/50
# 110/110 [==============================] - 126s 1s/step - loss: 0.1567 - accuracy: 0.9538 - val_loss: 1.1148 - val_accuracy: 0.5694
#
# Epoch 00050: val_loss did not improve from 0.53157

# %%
model.evaluate_generator(generator=validGenerator, steps=STEP_SIZE_VALID, verbose=1)
# Out:
# 21/21 [==============================] - 10s 494ms/step
# [0.7667936086654663, 0.5714285969734192]

# %%
model.load_weights('weights/model.ckpt')

# %%
model.evaluate_generator(generator=validGenerator, steps=STEP_SIZE_VALID, verbose=1)
# Out:
# 21/21 [==============================] - 10s 489ms/step
# [1.3189927339553833, 0.5879917144775391]

# %%
model.save_weights('weights/model.h5')

# %%
STEP_SIZE_TEST=testGenerator.n//testGenerator.batch_size
pred = model.predict_generator(testGenerator, steps=STEP_SIZE_TEST, verbose=1)
pred
# Out:
# 111/111 [==============================] - 93s 835ms/step
# array([[7.3502627e-03, 3.8988065e-02, 9.4088435e-01, 1.2777319e-02],
#        [1.2494288e-01, 2.4364052e-02, 5.0449836e-01, 3.4619471e-01],
#        [1.0984734e-04, 3.3915512e-06, 9.9906760e-01, 8.1914070e-04],
#        ...,
#        [6.2582636e-01, 2.7519016e-05, 3.7473146e-05, 3.7410861e-01],
#        [4.0103358e-05, 4.5134325e-02, 9.8777306e-04, 9.5383787e-01],
#        [5.6510672e-02, 1.0006525e-02, 4.3034058e-02, 8.9044875e-01]],
#       dtype=float32)

# %%
pred.shape
# Out:
# (3219, 4)

# %%
predicted_class_indices=np.argmax(pred,axis=1)
predicted_class_indices
# Out:
# array([2, 2, 2, ..., 0, 3, 3])

# %%
predicted_class_indices.shape
# Out:
# (3219,)

# %%
labels = (trainGenerator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in predicted_class_indices]
predictions
# Out:
# ['Food',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Attire',
#  'Decorationandsignage',
#  'misc',
#  'misc',
#  'Attire',
#  'Decorationandsignage',
#  'Decorationandsignage',
#  'misc',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'misc',
#  'misc',
#  'Attire',
#  'Food',
#  'misc',
#  'Attire',
#  'Attire',
#  'Food',
#  'Attire',
#  'Food',
#  'Attire',
#  'Food',
#  'misc',
#  'Attire',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Decorationandsignage',
#  'misc',
#  'Attire',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'misc',
#  'misc',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Food',
#  'Attire',
#  'Food',
#  'misc',
#  'Food',
#  'Food',
#  'Attire',
#  'misc',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'misc',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'misc',
#  'Attire',
#  'misc',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'misc',
#  'Attire',
#  'Attire',
#  'Food',
#  'misc',
#  'Food',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Food',
#  'misc',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'misc',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'misc',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'Attire',
#  'Attire',
#  'Decorationandsignage',
#  'Food',
#  'Attire',
#  'misc',
#  'misc',
#  'Food',
#  'Attire',
#  'misc',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'misc',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'Attire',
#  'Decorationandsignage',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'misc',
#  'Food',
#  'misc',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Decorationandsignage',
#  'Food',
#  'misc',
#  'Food',
#  'Attire',
#  'Attire',
#  'Food',
#  'Food',
#  'misc',
#  'Attire',
#  'Food',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'misc',
#  'Food',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'Food',
#  'Attire',
#  'Attire',
#  'Food',
#  'misc',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'Attire',
#  'Food',
#  'Attire',
#  'Food',
#  'Attire',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'misc',
#  'Decorationandsignage',
#  'Food',
#  'Attire',
#  'Food',
#  'misc',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'misc',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'misc',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'Attire',
#  'misc',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'misc',
#  'Attire',
#  'Decorationandsignage',
#  'Food',
#  'misc',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Attire',
#  'Food',
#  'Attire',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'Attire',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'misc',
#  'misc',
#  'Food',
#  'Attire',
#  'Food',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Food',
#  'Attire',
#  'Food',
#  'misc',
#  'misc',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'misc',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'Attire',
#  'Attire',
#  'Food',
#  'misc',
#  'Attire',
#  'Decorationandsignage',
#  'Food',
#  'misc',
#  'misc',
#  'misc',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'Attire',
#  'misc',
#  'Food',
#  'misc',
#  'Food',
#  'Food',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Decorationandsignage',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'Food',
#  'Attire',
#  'Attire',
#  'Food',
#  'misc',
#  'Food',
#  'Attire',
#  'Attire',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Attire',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Food',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Decorationandsignage',
#  'Food',
#  'misc',
#  'Attire',
#  'Attire',
#  'Decorationandsignage',
#  'Attire',
#  'Decorationandsignage',
#  'misc',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'misc',
#  'Attire',
#  'Decorationandsignage',
#  'misc',
#  'misc',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'misc',
#  'Decorationandsignage',
#  'misc',
#  'Attire',
#  'misc',
#  'Attire',
#  'misc',
#  'Food',
#  'misc',
#  'Food',
#  'Food',
#  'misc',
#  'Food',
#  'Decorationandsignage',
#  'misc',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Food',
#  'Attire',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'misc',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Decorationandsignage',
#  'Food',
#  'misc',
#  'Attire',
#  'Attire',
#  'Food',
#  'Attire',
#  'misc',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'Decorationandsignage',
#  'Attire',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'misc',
#  'Food',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'Food',
#  'misc',
#  'Attire',
#  'Decorationandsignage',
#  'Decorationandsignage',
#  'misc',
#  'misc',
#  'Food',
#  'Decorationandsignage',
#  'Decorationandsignage',
#  'Attire',
#  'Decorationandsignage',
#  'misc',
#  'Food',
#  'Attire',
#  'Food',
#  'misc',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'Attire',
#  'Food',
#  'misc',
#  'misc',
#  'Attire',
#  'Decorationandsignage',
#  'misc',
#  'Food',
#  'Decorationandsignage',
#  'Decorationandsignage',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'Food',
#  'Decorationandsignage',
#  'misc',
#  'Attire',
#  'Food',
#  'misc',
#  'Food',
#  'misc',
#  'Food',
#  'misc',
#  'Food',
#  'Decorationandsignage',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Attire',
#  'misc',
#  'Attire',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'misc',
#  'misc',
#  'Food',
#  'Attire',
#  'misc',
#  'Decorationandsignage',
#  'Decorationandsignage',
#  'misc',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'Food',
#  'Food',
#  'misc',
#  'misc',
#  'misc',
#  'Food',
#  'Decorationandsignage',
#  'Decorationandsignage',
#  'Attire',
#  'Attire',
#  'Decorationandsignage',
#  'Food',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Attire',
#  'misc',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'misc',
#  'misc',
#  'misc',
#  'Food',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'misc',
#  'misc',
#  'Attire',
#  'misc',
#  'Decorationandsignage',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'Food',
#  'misc',
#  'Decorationandsignage',
#  'Food',
#  'Attire',
#  'misc',
#  'Attire',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'misc',
#  'Attire',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'Food',
#  'Attire',
#  'Attire',
#  'Attire',
#  'misc',
#  'Decorationandsignage',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'misc',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'misc',
#  'Food',
#  'misc',
#  'Attire',
#  'misc',
#  'Decorationandsignage',
#  'Food',
#  'misc',
#  'Attire',
#  'Attire',
#  'Decorationandsignage',
#  'misc',
#  'Food',
#  'misc',
#  'misc',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'misc',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'misc',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'misc',
#  'Attire',
#  'Attire',
#  'Attire',
#  'misc',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'misc',
#  'misc',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'misc',
#  'Attire',
#  'Attire',
#  'Attire',
#  'misc',
#  'misc',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'misc',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'misc',
#  'Attire',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'misc',
#  'Decorationandsignage',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'misc',
#  'misc',
#  'Attire',
#  'Food',
#  'misc',
#  'Attire',
#  'Attire',
#  'Attire',
#  'misc',
#  'Attire',
#  'Food',
#  'misc',
#  'Food',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'misc',
#  'Attire',
#  'Attire',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Decorationandsignage',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Food',
#  'misc',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'Attire',
#  'Attire',
#  'Food',
#  'Attire',
#  'misc',
#  'Attire',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'Decorationandsignage',
#  'Decorationandsignage',
#  'Decorationandsignage',
#  'Attire',
#  'misc',
#  'Attire',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'Attire',
#  'Food',
#  'Attire',
#  'Attire',
#  'Decorationandsignage',
#  'Attire',
#  'Attire',
#  'Food',
#  'Attire',
#  'misc',
#  'misc',
#  'Attire',
#  'misc',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Attire',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Attire',
#  'Food',
#  'Food',
#  'Food',
#  'misc',
#  'Food',
#  'Food',
#  'misc',
#  'misc',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'misc',
#  'Food',
#  'Attire',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'Attire',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'misc',
#  'Attire',
#  'Attire',
#  'Food',
#  'misc',
#  'misc',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'misc',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'misc',
#  'Food',
#  'misc',
#  'Decorationandsignage',
#  'Food',
#  'misc',
#  'misc',
#  'Attire',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'misc',
#  'Attire',
#  'misc',
#  'Food',
#  'Attire',
#  'misc',
#  'Decorationandsignage',
#  'Food',
#  'misc',
#  'misc',
#  'Attire',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'Attire',
#  'misc',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'Decorationandsignage',
#  'Decorationandsignage',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'Attire',
#  'misc',
#  'Decorationandsignage',
#  'misc',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'misc',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'misc',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'misc',
#  'Decorationandsignage',
#  'misc',
#  'misc',
#  'misc',
#  'misc',
#  'Decorationandsignage',
#  'Attire',
#  'misc',
#  'Food',
#  'Attire',
#  'misc',
#  'Attire',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'Food',
#  'Attire',
#  'Attire',
#  'Attire',
#  'misc',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'misc',
#  'Food',
#  'Attire',
#  'Food',
#  'misc',
#  'Food',
#  'Decorationandsignage',
#  'Decorationandsignage',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'Attire',
#  'misc',
#  'Food',
#  'misc',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'misc',
#  'Attire',
#  'Decorationandsignage',
#  'Food',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'Attire',
#  'Food',
#  'misc',
#  'misc',
#  'Food',
#  'Food',
#  'misc',
#  'Decorationandsignage',
#  'Attire',
#  'misc',
#  'Attire',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'misc',
#  'Food',
#  'misc',
#  'Food',
#  'Attire',
#  'misc',
#  'Food',
#  'Food',
#  'misc',
#  'Decorationandsignage',
#  'Food',
#  'Attire',
#  'misc',
#  'Attire',
#  'Decorationandsignage',
#  'Attire',
#  'Attire',
#  'Food',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'misc',
#  'misc',
#  'misc',
#  'Food',
#  'misc',
#  'Attire',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'Food',
#  'Food',
#  'misc',
#  'misc',
#  'Food',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'misc',
#  'Food',
#  'Decorationandsignage',
#  'Decorationandsignage',
#  'Decorationandsignage',
#  'Food',
#  'Decorationandsignage',
#  'Decorationandsignage',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'Attire',
#  'misc',
#  'misc',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'misc',
#  'Food',
#  'Food',
#  'misc',
#  'Food',
#  'Decorationandsignage',
#  'Decorationandsignage',
#  'Food',
#  'misc',
#  'Decorationandsignage',
#  'Attire',
#  'misc',
#  'misc',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'Food',
#  ...]

# %%
filenames=testGenerator.filenames
results=pd.DataFrame({"Image":filenames, "Class":predictions})
results
# Out:
#                Image                 Class
# 0      image6245.jpg                  Food
# 1     image10409.jpg                  Food
# 2      image8692.jpg                  Food
# 3     image10517.jpg                  Food
# 4      image2580.jpg                Attire
# ...              ...                   ...
# 3214   image4968.jpg  Decorationandsignage
# 3215   image6673.jpg                  Food
# 3216   image3442.jpg                Attire
# 3217   image8178.jpg                  misc
# 3218   image5367.jpg                  misc
#
# [3219 rows x 2 columns]

# %%
results.groupby(by = 'Class', axis=0).count()
# Out:
#                       Image
# Class
# Attire                  856
# Decorationandsignage    474
# Food                   1206
# misc                    683

# %%
results.to_csv("output/output3.csv", index=False)
