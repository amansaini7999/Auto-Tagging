# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.applications import VGG16
from keras.layers import Dense, GlobalAveragePooling2D, Dropout
from keras.models import Model
from keras_preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
# Out:
# Using TensorFlow backend.
# /home/aman/.local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/aman/.local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/aman/.local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/aman/.local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/aman/.local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/aman/.local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/aman/.local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/aman/.local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/aman/.local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/aman/.local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/aman/.local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/aman/.local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
traindf = pd.read_csv("dataset/train.csv")
testdf = pd.read_csv("dataset/test.csv")

# %%
traindf.head()
# Out:
#             Image   Class
# 0   image7042.jpg    Food
# 1   image3327.jpg    misc
# 2  image10335.jpg  Attire
# 3   image8019.jpg    Food
# 4   image2128.jpg  Attire

# %%
testdf.head()
# Out:
#             Image
# 0   image6245.jpg
# 1  image10409.jpg
# 2   image8692.jpg
# 3  image10517.jpg
# 4   image2580.jpg

# %%
len(traindf)
# Out:
# 5983

# %%
len(testdf)
# Out:
# 3219

# %%
traindf.groupby(by = 'Class', axis=0).count()
# Out:
#                       Image
# Class
# Attire                 1691
# Decorationandsignage    743
# Food                   2278
# misc                   1271

# %%
trainPath = "dataset/Train Images/"
testPath = "dataset/Test Images/"

# %%
datagen=ImageDataGenerator(rescale=1./255., validation_split=0.0808, horizontal_flip=True)

# %%
trainGenerator=datagen.flow_from_dataframe(dataframe=traindf,
                                           directory=trainPath,
                                           x_col="Image",
                                           y_col="Class",
                                           batch_size=50,
                                           subset="training",
                                           seed=42,
                                           shuffle=True,
                                           class_mode="categorical",
                                           target_size=(60,80))

validGenerator=datagen.flow_from_dataframe(dataframe=traindf,
                                           directory=trainPath,
                                           x_col="Image",
                                           y_col="Class",
                                           batch_size=23,
                                           subset="validation",
                                           seed=42,
                                           shuffle=True,
                                           class_mode="categorical",
                                           target_size=(60,80))
# Out:
# Found 5500 validated image filenames belonging to 4 classes.
# Found 483 validated image filenames belonging to 4 classes.

# %%
testDatagen=ImageDataGenerator(rescale=1./255.)

testGenerator=testDatagen.flow_from_dataframe(dataframe=testdf,
                                                directory=testPath,
                                                x_col="Image",
                                                y_col=None,
                                                batch_size=29,
                                                seed=42,
                                                shuffle=False,
                                                class_mode=None,
                                                target_size=(60,80))
# Out:
# Found 3219 validated image filenames.

# %%
def buildModel():
    baseModel = VGG16(input_shape=(60, 80, 3), weights='imagenet',include_top=False)
    model = Sequential()
    model.add(baseModel)
    model.add(GlobalAveragePooling2D())
    
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(4, activation='softmax'))
    
    baseModel.trainable=False
    
    set_trainable = False
    for layer in baseModel.layers:
        if layer.name == 'layer_name':
            set_trainable = True
        
        if set_trainable:
            layer.trainable = True
        else:
            layer.trainable = False
    
    model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'])
    
    return baseModel, model

# %%
baseModel, model = buildModel()

baseModel.summary()
model.summary()
# Out:
# WARNING:tensorflow:From /home/aman/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 60, 80, 3)         0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 60, 80, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 60, 80, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 30, 40, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 30, 40, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 30, 40, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 15, 20, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 15, 20, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 15, 20, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 15, 20, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 7, 10, 256)        0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 7, 10, 512)        1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 7, 10, 512)        2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 7, 10, 512)        2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 3, 5, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 3, 5, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 3, 5, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 3, 5, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 1, 2, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 1, 2, 512)         14714688
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 1028
# =================================================================
# Total params: 14,847,044
# Trainable params: 132,356
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
STEP_SIZE_TRAIN=trainGenerator.n//trainGenerator.batch_size
STEP_SIZE_VALID=validGenerator.n//validGenerator.batch_size

checkpointer = ModelCheckpoint(filepath='weights/model.ckpt', verbose=1, save_best_only=True)

# %%
model.fit_generator(generator=trainGenerator, steps_per_epoch=STEP_SIZE_TRAIN, validation_data=validGenerator, validation_steps=STEP_SIZE_VALID, epochs=50, verbose=1, callbacks=[checkpointer])
# Out:
# WARNING:tensorflow:From /home/aman/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/20
# 110/110 [==============================] - 164s 1s/step - loss: 1.1006 - accuracy: 0.5182 - val_loss: 1.3519 - val_accuracy: 0.5611
#
# Epoch 00001: val_loss improved from inf to 1.35195, saving model to weights/model.ckpt
# Epoch 2/20
# 110/110 [==============================] - 214s 2s/step - loss: 0.9632 - accuracy: 0.5978 - val_loss: 1.1181 - val_accuracy: 0.5652
#
# Epoch 00002: val_loss improved from 1.35195 to 1.11810, saving model to weights/model.ckpt
# Epoch 3/20
# 110/110 [==============================] - 183s 2s/step - loss: 0.9114 - accuracy: 0.6204 - val_loss: 0.8378 - val_accuracy: 0.5921
#
# Epoch 00003: val_loss improved from 1.11810 to 0.83784, saving model to weights/model.ckpt
# Epoch 4/20
# 110/110 [==============================] - 153s 1s/step - loss: 0.8708 - accuracy: 0.6400 - val_loss: 0.9210 - val_accuracy: 0.6004
#
# Epoch 00004: val_loss did not improve from 0.83784
# Epoch 5/20
# 110/110 [==============================] - 168s 2s/step - loss: 0.8396 - accuracy: 0.6591 - val_loss: 0.9034 - val_accuracy: 0.6025
#
# Epoch 00005: val_loss did not improve from 0.83784
# Epoch 6/20
# 110/110 [==============================] - 140s 1s/step - loss: 0.8125 - accuracy: 0.6758 - val_loss: 1.2211 - val_accuracy: 0.6211
#
# Epoch 00006: val_loss did not improve from 0.83784
# Epoch 7/20
# 110/110 [==============================] - 138s 1s/step - loss: 0.7920 - accuracy: 0.6778 - val_loss: 1.3108 - val_accuracy: 0.6087
#
# Epoch 00007: val_loss did not improve from 0.83784
# Epoch 8/20
# 110/110 [==============================] - 161s 1s/step - loss: 0.7578 - accuracy: 0.6911 - val_loss: 0.6769 - val_accuracy: 0.6046
#
# Epoch 00008: val_loss improved from 0.83784 to 0.67685, saving model to weights/model.ckpt
# Epoch 9/20
# 110/110 [==============================] - 180s 2s/step - loss: 0.7345 - accuracy: 0.7069 - val_loss: 0.8374 - val_accuracy: 0.6149
#
# Epoch 00009: val_loss did not improve from 0.67685
# Epoch 10/20
# 110/110 [==============================] - 140s 1s/step - loss: 0.7058 - accuracy: 0.7196 - val_loss: 0.7148 - val_accuracy: 0.6004
#
# Epoch 00010: val_loss did not improve from 0.67685
# Epoch 11/20
# 110/110 [==============================] - 181s 2s/step - loss: 0.6790 - accuracy: 0.7320 - val_loss: 1.0018 - val_accuracy: 0.6211
#
# Epoch 00011: val_loss did not improve from 0.67685
# Epoch 12/20
# 110/110 [==============================] - 196s 2s/step - loss: 0.6594 - accuracy: 0.7445 - val_loss: 0.9290 - val_accuracy: 0.5921
#
# Epoch 00012: val_loss did not improve from 0.67685
# Epoch 13/20
# 110/110 [==============================] - 211s 2s/step - loss: 0.6354 - accuracy: 0.7491 - val_loss: 0.8935 - val_accuracy: 0.6190
#
# Epoch 00013: val_loss did not improve from 0.67685
# Epoch 14/20
# 110/110 [==============================] - 176s 2s/step - loss: 0.6296 - accuracy: 0.7573 - val_loss: 0.9911 - val_accuracy: 0.5921
#
# Epoch 00014: val_loss did not improve from 0.67685
# Epoch 15/20
# 110/110 [==============================] - 176s 2s/step - loss: 0.5997 - accuracy: 0.7685 - val_loss: 0.8142 - val_accuracy: 0.6190
#
# Epoch 00015: val_loss did not improve from 0.67685
# Epoch 16/20
# 110/110 [==============================] - 176s 2s/step - loss: 0.5739 - accuracy: 0.7789 - val_loss: 0.9499 - val_accuracy: 0.6004
#
# Epoch 00016: val_loss did not improve from 0.67685
# Epoch 17/20
# 110/110 [==============================] - 146s 1s/step - loss: 0.5484 - accuracy: 0.7905 - val_loss: 1.0396 - val_accuracy: 0.5983
#
# Epoch 00017: val_loss did not improve from 0.67685
# Epoch 18/20
# 110/110 [==============================] - 156s 1s/step - loss: 0.5318 - accuracy: 0.7976 - val_loss: 0.8118 - val_accuracy: 0.6149
#
# Epoch 00018: val_loss did not improve from 0.67685
# Epoch 19/20
# 110/110 [==============================] - 167s 2s/step - loss: 0.5072 - accuracy: 0.8107 - val_loss: 0.5738 - val_accuracy: 0.5983
#
# Epoch 00019: val_loss improved from 0.67685 to 0.57385, saving model to weights/model.ckpt
# Epoch 20/20
# 110/110 [==============================] - 142s 1s/step - loss: 0.4892 - accuracy: 0.8191 - val_loss: 0.8863 - val_accuracy: 0.5963
#
# Epoch 00020: val_loss did not improve from 0.57385

# %%
model.evaluate_generator(generator=validGenerator, steps=STEP_SIZE_VALID, verbose=1)
# Out:
# 21/21 [==============================] - 11s 510ms/step
# [1.0676584243774414, 0.6004140973091125]

# %%
model.load_weights('weights/model.ckpt')

# %%
model.evaluate_generator(generator=validGenerator, steps=STEP_SIZE_VALID, verbose=1)
# Out:
# 21/21 [==============================] - 11s 531ms/step
# [1.0132445096969604, 0.5983436703681946]

# %%
model.save_weights('weights/model.h5')

# %%
STEP_SIZE_TEST=testGenerator.n//testGenerator.batch_size
pred = model.predict_generator(testGenerator, steps=STEP_SIZE_TEST, verbose=1)
pred
# Out:
# 111/111 [==============================] - 76s 688ms/step
# array([[8.38393569e-02, 8.25730860e-02, 7.27837503e-01, 1.05750039e-01],
#        [3.42454880e-01, 1.59195531e-02, 5.17086565e-01, 1.24539025e-01],
#        [7.44958827e-03, 3.78686964e-04, 9.71909821e-01, 2.02620048e-02],
#        ...,
#        [5.26317537e-01, 3.30222188e-04, 1.32207386e-02, 4.60131556e-01],
#        [6.70368783e-03, 5.64946719e-02, 3.72311175e-02, 8.99570465e-01],
#        [7.55466670e-02, 8.22844449e-03, 1.23158336e-01, 7.93066621e-01]],
#       dtype=float32)

# %%
pred.shape
# Out:
# (3219, 4)

# %%
predicted_class_indices=np.argmax(pred,axis=1)
predicted_class_indices
# Out:
# array([2, 2, 2, ..., 0, 3, 3])

# %%
predicted_class_indices.shape
# Out:
# (3219,)

# %%
labels = (trainGenerator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in predicted_class_indices]
predictions
# Out:
# ['Food',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Attire',
#  'Attire',
#  'misc',
#  'misc',
#  'Attire',
#  'Decorationandsignage',
#  'Decorationandsignage',
#  'Decorationandsignage',
#  'misc',
#  'Food',
#  'Food',
#  'Attire',
#  'misc',
#  'misc',
#  'Attire',
#  'Food',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Food',
#  'Attire',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'Attire',
#  'Attire',
#  'Food',
#  'Food',
#  'Food',
#  'misc',
#  'Attire',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'misc',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Food',
#  'Attire',
#  'Food',
#  'misc',
#  'Food',
#  'misc',
#  'Attire',
#  'misc',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'misc',
#  'Attire',
#  'misc',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'misc',
#  'Attire',
#  'Food',
#  'misc',
#  'misc',
#  'Attire',
#  'Food',
#  'misc',
#  'Food',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'misc',
#  'Attire',
#  'Food',
#  'Attire',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'misc',
#  'Food',
#  'misc',
#  'Decorationandsignage',
#  'Attire',
#  'Attire',
#  'Decorationandsignage',
#  'Food',
#  'Attire',
#  'misc',
#  'Food',
#  'Food',
#  'Attire',
#  'misc',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'Attire',
#  'Food',
#  'Attire',
#  'Attire',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'Attire',
#  'misc',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'misc',
#  'Food',
#  'Food',
#  'Attire',
#  'misc',
#  'Attire',
#  'misc',
#  'Food',
#  'Attire',
#  'Food',
#  'Attire',
#  'Attire',
#  'Food',
#  'Food',
#  'misc',
#  'Attire',
#  'Food',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'Attire',
#  'misc',
#  'Food',
#  'misc',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'Attire',
#  'Food',
#  'misc',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'Attire',
#  'misc',
#  'Attire',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'misc',
#  'Decorationandsignage',
#  'Food',
#  'Attire',
#  'Food',
#  'misc',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'Attire',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Food',
#  'misc',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'Attire',
#  'Attire',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'Food',
#  'misc',
#  'Attire',
#  'Decorationandsignage',
#  'Attire',
#  'misc',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Food',
#  'Attire',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'Attire',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'Food',
#  'misc',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Food',
#  'Attire',
#  'Attire',
#  'Food',
#  'Food',
#  'Attire',
#  'Food',
#  'misc',
#  'misc',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'misc',
#  'misc',
#  'Decorationandsignage',
#  'Food',
#  'misc',
#  'Attire',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'Food',
#  'misc',
#  'Attire',
#  'Food',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'Attire',
#  'Food',
#  'Food',
#  'Attire',
#  'Food',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Attire',
#  'misc',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'misc',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'Food',
#  'misc',
#  'Food',
#  'Attire',
#  'Attire',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Attire',
#  'misc',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'misc',
#  'Attire',
#  'Decorationandsignage',
#  'misc',
#  'misc',
#  'Food',
#  'Attire',
#  'Food',
#  'misc',
#  'Attire',
#  'Food',
#  'Food',
#  'misc',
#  'Decorationandsignage',
#  'Food',
#  'Attire',
#  'misc',
#  'Attire',
#  'misc',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'misc',
#  'Food',
#  'Decorationandsignage',
#  'misc',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'misc',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Food',
#  'Food',
#  'Food',
#  'misc',
#  'Attire',
#  'Food',
#  'Attire',
#  'misc',
#  'misc',
#  'Attire',
#  'Food',
#  'misc',
#  'Attire',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'Attire',
#  'Food',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'Attire',
#  'Attire',
#  'Food',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'Decorationandsignage',
#  'misc',
#  'misc',
#  'Food',
#  'misc',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'misc',
#  'Attire',
#  'Attire',
#  'Food',
#  'Food',
#  'misc',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'Attire',
#  'Food',
#  'misc',
#  'misc',
#  'Attire',
#  'Decorationandsignage',
#  'misc',
#  'misc',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'Food',
#  'Attire',
#  'Food',
#  'misc',
#  'Food',
#  'misc',
#  'Food',
#  'misc',
#  'Food',
#  'misc',
#  'Food',
#  'misc',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Attire',
#  'misc',
#  'Attire',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Food',
#  'Attire',
#  'Food',
#  'Attire',
#  'Attire',
#  'Decorationandsignage',
#  'Decorationandsignage',
#  'misc',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'misc',
#  'Food',
#  'Food',
#  'misc',
#  'Decorationandsignage',
#  'Attire',
#  'Attire',
#  'Decorationandsignage',
#  'misc',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Attire',
#  'misc',
#  'Food',
#  'Attire',
#  'misc',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'misc',
#  'misc',
#  'misc',
#  'Food',
#  'Food',
#  'Attire',
#  'Food',
#  'Attire',
#  'misc',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'Attire',
#  'misc',
#  'Attire',
#  'Attire',
#  'Food',
#  'Food',
#  'misc',
#  'Attire',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Decorationandsignage',
#  'Decorationandsignage',
#  'Food',
#  'misc',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'misc',
#  'Food',
#  'misc',
#  'Attire',
#  'misc',
#  'Decorationandsignage',
#  'Food',
#  'misc',
#  'Attire',
#  'Attire',
#  'Decorationandsignage',
#  'misc',
#  'Food',
#  'misc',
#  'misc',
#  'Decorationandsignage',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'misc',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'Food',
#  'misc',
#  'Decorationandsignage',
#  'misc',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'misc',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'misc',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'misc',
#  'misc',
#  'Food',
#  'Food',
#  'Attire',
#  'Food',
#  'misc',
#  'Attire',
#  'Attire',
#  'Attire',
#  'misc',
#  'misc',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'misc',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'misc',
#  'Attire',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Food',
#  'misc',
#  'Decorationandsignage',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'misc',
#  'Food',
#  'Attire',
#  'Food',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'misc',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Food',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Food',
#  'misc',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'Attire',
#  'Attire',
#  'Food',
#  'Attire',
#  'misc',
#  'Attire',
#  'Food',
#  'Food',
#  'Attire',
#  'misc',
#  'Food',
#  'Decorationandsignage',
#  'misc',
#  'Attire',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Attire',
#  'Decorationandsignage',
#  'Attire',
#  'Attire',
#  'Food',
#  'Food',
#  'Attire',
#  'misc',
#  'Attire',
#  'Attire',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Attire',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Attire',
#  'Food',
#  'Attire',
#  'Food',
#  'misc',
#  'misc',
#  'Food',
#  'Food',
#  'misc',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'misc',
#  'Attire',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'Attire',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Food',
#  'misc',
#  'Attire',
#  'Food',
#  'Attire',
#  'misc',
#  'Food',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'misc',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'misc',
#  'Food',
#  'misc',
#  'misc',
#  'Food',
#  'misc',
#  'misc',
#  'Attire',
#  'Attire',
#  'Food',
#  'Food',
#  'misc',
#  'Attire',
#  'misc',
#  'Attire',
#  'misc',
#  'Food',
#  'Attire',
#  'misc',
#  'Attire',
#  'Food',
#  'Attire',
#  'Food',
#  'Attire',
#  'Food',
#  'Attire',
#  'Food',
#  'misc',
#  'Food',
#  'misc',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'misc',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'Attire',
#  'Attire',
#  'Attire',
#  'misc',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'misc',
#  'Food',
#  'Attire',
#  'Food',
#  'misc',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'Attire',
#  'Attire',
#  'Decorationandsignage',
#  'misc',
#  'misc',
#  'misc',
#  'misc',
#  'Decorationandsignage',
#  'Food',
#  'Food',
#  'Food',
#  'Attire',
#  'misc',
#  'Attire',
#  'Attire',
#  'Attire',
#  'Decorationandsignage',
#  'Food',
#  'Attire',
#  'Attire',
#  'Attire',
#  'misc',
#  'misc',
#  'Food',
#  'Decorationandsignage',
#  'misc',
#  'Food',
#  'Attire',
#  'Food',
#  'misc',
#  'Food',
#  'Decorationandsignage',
#  'Decorationandsignage',
#  'Food',
#  'misc',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'Attire',
#  'misc',
#  'Food',
#  'misc',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'misc',
#  'Attire',
#  'Decorationandsignage',
#  'Food',
#  'Attire',
#  'Food',
#  'Decorationandsignage',
#  'Decorationandsignage',
#  'Attire',
#  'Attire',
#  'misc',
#  'misc',
#  'Food',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'misc',
#  'Attire',
#  'Attire',
#  'Food',
#  'misc',
#  'Attire',
#  'misc',
#  'Food',
#  'misc',
#  'Food',
#  'Attire',
#  'Attire',
#  'Food',
#  'Food',
#  'misc',
#  'Attire',
#  'Food',
#  'Food',
#  'misc',
#  'Attire',
#  'Decorationandsignage',
#  'Attire',
#  'Attire',
#  'Food',
#  'Food',
#  'Attire',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'misc',
#  'misc',
#  'misc',
#  'Food',
#  'misc',
#  'Attire',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'Food',
#  'Food',
#  'misc',
#  'misc',
#  'Food',
#  'Attire',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'Decorationandsignage',
#  'Decorationandsignage',
#  'Food',
#  'Decorationandsignage',
#  'Attire',
#  'Food',
#  'Food',
#  'Attire',
#  'Food',
#  'Attire',
#  'misc',
#  'misc',
#  'Food',
#  'misc',
#  'Food',
#  'misc',
#  'Food',
#  'Attire',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  'Decorationandsignage',
#  'Food',
#  'misc',
#  'Food',
#  'Attire',
#  'misc',
#  'Attire',
#  'misc',
#  'Food',
#  'Food',
#  'Decorationandsignage',
#  ...]

# %%
filenames=testGenerator.filenames
results=pd.DataFrame({"Image":filenames, "Class":predictions})
results
# Out:
#             Filename Predictions
# 0      image6245.jpg        Food
# 1     image10409.jpg        Food
# 2      image8692.jpg        Food
# 3     image10517.jpg        Food
# 4      image2580.jpg      Attire
# ...              ...         ...
# 3214   image4968.jpg      Attire
# 3215   image6673.jpg        Food
# 3216   image3442.jpg      Attire
# 3217   image8178.jpg        misc
# 3218   image5367.jpg        misc
#
# [3219 rows x 2 columns]

# %%
results.to_csv("output/output3.csv", index=False)
